# %%
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/patzer_adi/Documents/python/Python_Workspace/Aditya_SEM_3_assignments/class_assignment_3/online_food_delivery_dataset.csv')

# %% [markdown]
# ##Question 1

# %%
df.head(5)
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size Customer Type  latitude  longitude  \
# 0              Post Graduate            4      Frequent   12.9766    77.5993
# 1                   Graduate            3       Regular   12.9770    77.5773
# 2              Post Graduate            3       Regular   12.9551    77.6593
# 3                   Graduate            6      Frequent   12.9473    77.5616
# 4              Post Graduate            4      Frequent   12.9850    77.5533
#
#    Pin code Output   Feedback Unnamed: 13
# 0    560001    Yes   Positive         Yes
# 1    560009    Yes   Positive         Yes
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size Customer Type  latitude  \
# 0                Post Graduate            4      Frequent   12.9766
# 1                     Graduate            3       Regular   12.9770
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'Customer Type',
#        'latitude', 'longitude', 'Pin code', 'Output', 'Feedback',
#        'Unnamed: 13'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                             int64
# Gender                         object
# Marital Status                 object
# Occupation                     object
# Monthly Income                 object
# Educational Qualifications     object
# Family size                     int64
# Customer Type                  object
# latitude                      float64
# longitude                     float64
# Pin code                        int64
# Output                         object
# Feedback                       object
# Unnamed: 13                    object
# dtype: object

# %% [markdown]
# ## Question 2

# %%
df['Age'].mean()
# Out:
# np.float64(24.628865979381445)

# %%
df['Age'].max()
# Out:
# np.int64(33)

# %%
df['Age'].min()
# Out:
# np.int64(18)

# %%
df['Gender']).value_counts()
# Out:
# Gender
# Male      222
# Female    166
# Name: count, dtype: int64

# %% [markdown]
# ## QUestion 3

# %%
mask = (df["Age"] > 25) & (df["Occupation"] == "Employee")
df[mask]
# Out:
#      Age  Gender     Marital Status Occupation   Monthly Income  \
# 5     27  Female            Married   Employee  More than 50000
# 16    28  Female             Single   Employee   25001 to 50000
# 58    31    Male            Married   Employee  More than 50000
# 90    27  Female  Prefer not to say   Employee   25001 to 50000
# 98    26    Male            Married   Employee   25001 to 50000
# ..   ...     ...                ...        ...              ...
# 369   30    Male            Married   Employee  More than 50000
# 371   28    Male            Married   Employee   25001 to 50000
# 375   26  Female            Married   Employee   Below Rs.10000
# 377   31    Male  Prefer not to say   Employee   Below Rs.10000
# 380   27  Female            Married   Employee  More than 50000
#
#     Educational Qualifications  Family size Customer Type  latitude  \
# 5                Post Graduate            2       Regular   12.9299
# ...

# %%
df[["Age", "Gender", "Occupation", "Monthly Income"]]
# Out:
#      Age  Gender Occupation  Monthly Income
# 0     20  Female    Student       No Income
# 1     24  Female    Student  Below Rs.10000
# 2     22    Male    Student  Below Rs.10000
# 3     22  Female    Student       No Income
# 4     22    Male    Student  Below Rs.10000
# ..   ...     ...        ...             ...
# 383   23  Female    Student       No Income
# 384   23  Female    Student       No Income
# 385   22  Female    Student       No Income
# 386   23    Male    Student  Below Rs.10000
# 387   23    Male    Student       No Income
#
# [388 rows x 4 columns]

# %% [markdown]
# ## Question 4

# %%
result = df.groupby("Occupation")["Age"].mean()
result
# Out:
# Occupation
# Employee          26.576271
# House wife        30.333333
# Self Employeed    26.388889
# Student           22.811594
# Name: Age, dtype: float64

# %%
result.idxmax(), result.max()
# Out:
# ('House wife', np.float64(30.333333333333332))

# %% [markdown]
# ## Question 5

# %%
feedback_count = df['Feedback'].value_counts()
feedback_count
# Out:
# Feedback
# Positive     317
# Negative      71
# Name: count, dtype: int64

# %%
print(f"Postive percetage: {(df['Feedback'] == 'Positive').mean() * 100} %")
# Out:
# Postive percetage: 81.70103092783505 %

# %%
print(f"Negative percetage: {(df['Feedback'] == 'Negative').mean() * 100} %")
# Out:
# Negative percetage: 0.0 %

# %% [markdown]
# ## Question 6

# %%
results = df.groupby(['Occupation', 'Feedback']).size()
results
# Out:
# Occupation      Feedback
# Employee        Negative      33
#                 Positive      85
# House wife      Negative       1
#                 Positive       8
# Self Employeed  Negative      16
#                 Positive      38
# Student         Negative      21
#                 Positive     186
# dtype: int64

# %%
results = df.groupby(['Occupation', 'Feedback']).size().unstack()
results
# Out:
# Feedback        Negative   Positive
# Occupation
# Employee               33        85
# House wife              1         8
# Self Employeed         16        38
# Student                21       186

# %%
## Question 7 & 8 & 9 & 10

# %%
class BankAccount:
    def __init__(self, account_num, owner, balance=0):
        self.account_num = account_num
        self.owner= owner
        self.balance = balance


    def __str__(self):
        return f"{self.account_num} | {self.owner}: ₹{self.balance}"

    def __eq__(self,other):
        return self.account_num == other.account_num  

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            return True
        else:
            return False

# %%
account_1 = BankAccount(account_num=107,owner='Adi',balance=12000)

# %%
account_1.deposit(120)

# %%
account_1.balance
# Out:
# 12120

# %%
account_1.withdraw(1000)
# Out:
# True

# %%
account_1.balance
# Out:
# 11120

# %%
print(account_1)
# Out:
# 107 | Adi: ₹11120

# %% [markdown]
# ## question 11

# %%
class Student:
    def __init__(self, name, roll_no, marks=[]):
        self.name = name
        self.roll_no= roll_no
        self.marks = marks

    def average_marks(self, amount):
        self.balance += amount
