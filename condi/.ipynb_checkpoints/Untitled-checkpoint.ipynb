# %%
i = int(input("Enter a number:"))


if i in range(1,10):
    print("small no")
elif i in range(11,20):
    print("not so big")
else:
    print("very large number")
# Out:
# Enter a number: 7
# small no
