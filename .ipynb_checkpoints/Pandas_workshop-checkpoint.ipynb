# %%
students = [
    ["Aarav", 85, 78, 92],
    ["Riya", 91, 88, 95],
    ["Kabir", 72, 69, 80],
]

# %%
students
# Out:
# [['Aarav', 85, 78, 92], ['Riya', 91, 88, 95], ['Kabir', 72, 69, 80]]

# %%
type(students)
# Out:
# list

# %%
import pandas as pd

# %%
# code here
students = [
    ["Alice", 21, "Pune", 85],
    ["Bob", 22, "Mumbai", 91],
    ["Charlie", 20, "Pune", 78]
]
print(students)

df = pd.DataFrame(
    students,
    columns=["Name", "Age", "City", "Score"]
)
print('\n')
print(df)
# Out:
# [['Alice', 21, 'Pune', 85], ['Bob', 22, 'Mumbai', 91], ['Charlie', 20, 'Pune', 78]]
#
#
#       Name  Age    City  Score
# 0    Alice   21    Pune     85
# 1      Bob   22  Mumbai     91
# 2  Charlie   20    Pune     78

# %%
# code here

## Try this with the df you have created and see what all output you get?

df.head(1)
# Out:
#     Name  Age  City  Score
# 0  Alice   21  Pune     85

# %%
df.tail(1)
# Out:
#       Name  Age  City  Score
# 2  Charlie   20  Pune     78

# %%
df.shape
# Out:
# (3, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Score'], dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df["Name"]
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: str

# %%
df.dtypes
# Out:
# Name       str
# Age      int64
# City       str
# Score    int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of       Name  Age    City  Score
# 0    Alice   21    Pune     85
# 1      Bob   22  Mumbai     91
# 2  Charlie   20    Pune     78>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Name  Age    City  Score
# 0    Alice   21    Pune     85
# 1      Bob   22  Mumbai     91
# 2  Charlie   20    Pune     78>

# %%
df[["Name", "Score"]]
# Out:
#       Name  Score
# 0    Alice     85
# 1      Bob     91
# 2  Charlie     78

# %%
df[["City"]]
# Out:
#      City
# 0    Pune
# 1  Mumbai
# 2    Pune

# %%
df[["Name", "City"]]
# Out:
#       Name    City
# 0    Alice    Pune
# 1      Bob  Mumbai
# 2  Charlie    Pune

# %%
df[["Name", "Age", "Score"]]
# Out:
#       Name  Age  Score
# 0    Alice   21     85
# 1      Bob   22     91
# 2  Charlie   20     78

# %%
type(df["Age"])
# Out:
# pandas.Series

# %%
df["Name"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.iloc[0]
# Out:
# Name     Alice
# Age         21
# City      Pune
# Score       85
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Name        Bob
# Age          22
# City     Mumbai
# Score        91
# Name: 1, dtype: object

# %%
df.iloc[0:2]
# Out:
#     Name  Age    City  Score
# 0  Alice   21    Pune     85
# 1    Bob   22  Mumbai     91

# %%
df.iloc[0:2, 0:2]
# Out:
#     Name  Age
# 0  Alice   21
# 1    Bob   22

# %%
df.loc[0]
# Out:
# Name     Alice
# Age         21
# City      Pune
# Score       85
# Name: 0, dtype: object

# %%
df.loc[1]
# Out:
# Name        Bob
# Age          22
# City     Mumbai
# Score        91
# Name: 1, dtype: object

# %%
df.iloc[-1]
# Out:
# Name     Charlie
# Age           20
# City        Pune
# Score         78
# Name: 2, dtype: object

# %%
df.loc[1, ["Name", "Age"]]
# Out:
# Name    Bob
# Age      22
# Name: 1, dtype: object

# %%
df.iloc[1, 3]
# Out:
# np.int64(91)

# %%
df_custom = df.copy()

df_custom.index = ["student_A", "student_B", "student_C"]

df_custom
# Out:
#               Name  Age    City  Score
# student_A    Alice   21    Pune     85
# student_B      Bob   22  Mumbai     91
# student_C  Charlie   20    Pune     78

# %%
df.loc[0]
# Out:
# Name     Alice
# Age         21
# City      Pune
# Score       85
# Name: 0, dtype: object

# %%
df_custom = df.copy()

df_custom.index = ["student_A", "student_B", "student_C"]

df_custom
# Out:
#               Name  Age    City  Score
# student_A    Alice   21    Pune     85
# student_B      Bob   22  Mumbai     91
# student_C  Charlie   20    Pune     78

# %%
df_custom.loc["student_B"]
# Out:
# Name        Bob
# Age          22
# City     Mumbai
# Score        91
# Name: student_B, dtype: object

# %%
df_custom.iloc[1]
# Out:
# Name        Bob
# Age          22
# City     Mumbai
# Score        91
# Name: student_B, dtype: object

# %%
df_custom.loc["student_B", "Score"]
# Out:
# np.int64(91)

# %%
df_custom.loc["student_B", ["Name", "City", "Score"]]
# Out:
# Name        Bob
# City     Mumbai
# Score        91
# Name: student_B, dtype: object

# %%
df_custom.loc[["student_A", "student_C"]]
# Out:
#               Name  Age  City  Score
# student_A    Alice   21  Pune     85
# student_C  Charlie   20  Pune     78

# %%
df_custom.loc["student_A"]
#we did try travesing through labels
# Out:
# Name     Alice
# Age         21
# City      Pune
# Score       85
# Name: student_A, dtype: object

# %%
df_custom.loc["student_C", "City"]
#it is doing the  city update
# Out:
# 'Pune'

# %%
df_custom.loc["student_B", ["Name", "Score"]]
#we have to get name and score of stu3
# Out:
# Name     Bob
# Score     91
# Name: student_B, dtype: object

# %%
df_custom.loc[["student_A", "student_C"]]
# Out:
#               Name  Age  City  Score
# student_A    Alice   21  Pune     85
# student_C  Charlie   20  Pune     78

# %%
df_custom.loc["student_A":"student_B"]
# Out:
#             Name  Age    City  Score
# student_A  Alice   21    Pune     85
# student_B    Bob   22  Mumbai     91

# %%
df_custom.loc[["student_A", "student_C"], ["Name", "Score"]]
# Out:
#               Name  Score
# student_A    Alice     85
# student_C  Charlie     78
