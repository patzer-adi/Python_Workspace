# %%
# Experiment 1

a = 10
b = 20
a, b = b, a
print(a)
print(b)
# Out:
# 20
# 10

# %%
# Experiment 2

text = "Python Programming"
print(text[0])
print(text[-1])
print(text[0:6])
print(text[::-1])
# Out:
# P
# g
# Python
# gnimmargorP nohtyP

# %%
# Experiment 3

numbers = [10,20,30]
numbers.append(40)
numbers.remove(20)
print(numbers)
# Out:
# [10, 30, 40]

# %%
# Experiment 4

text = "Programming"
print(text[0:5])
print(text[3:])
print(text[:6])
print(text[::-1])
# Out:
# Progr
# gramming
# Progra
# gnimmargorP

# %%
# Experiment 5

age = input("Enter your age : ")
print(age + age)
age = int(age)
print(age + age)
# Out:
# Enter your age :  21
# 2121
# 42

# %% [markdown]
# Question: Why are the two outputs different?
#
# Firstly we have used input function that simply takes an value in form of a string. And then we have performed string concatenation that simply join two strings together. Then we have converted age to integer and then performed addition so the answer is 42.

# %%
#Experiment 6

fruits = ["Apple", "Banana", "Mango", "Orange"]
print(fruits[0])
print(fruits[-1])
print(fruits[1:3])
# Out:
# Apple
# Orange
# ['Banana', 'Mango']

# %%
# Experiment 7

numbers = [10,20,30]
numbers[1] = 200
print(numbers)
# Out:
# [10, 200, 30]

# %% [markdown]
# Question: Why can a list be modified while a string cannot?
#
# A list can be modified because list is mutable which means its elements can be added, removed, or updated after the list is created. Whereas, a string is immutable which means its characters cannot be changed once the string is created.

# %%
# Experiment 8

print("=" * 40)
print("WELCOME")
print("=" * 40)
print()
print("*" * 20)
print("Python")
print("*" * 20)
# Out:
# ...
# WELCOME
# ...
#
# ********************
# Python
# ********************

# %%
# Experiment 9

name = input("Enter your name: ")
reverse_name = name[::-1]
print(reverse_name)
# Out:
# Enter your name:  Saily
# yliaS

# %%
# Experiment 10

name = input("Enter your name: ")
age = input("Enter your age: ")
roll_no = input("Enter your roll number: ")
course = input("Enter your course: ")

print("============================")
print("        STUDENT CARD")
print("="*28)
print("Name     :", name)
print("Age      :", age)
print("Roll No. :", roll_no)
print("Course   :", course)
print("============================")
print("Hello", name + "!")
print("Welcome to the world of Python.")
print("\"Python is easy to learn!\"")
print("'I'll practice every day.'")
print("\"Practice makes perfect.\"")
print("\\/"*28)
print("Happy Coding!")
# Out:
# Enter your name:  Alice
# Enter your age:  22
