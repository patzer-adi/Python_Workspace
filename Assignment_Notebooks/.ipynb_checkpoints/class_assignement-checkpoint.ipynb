# %% [markdown]
# ## Assignment 2

# %%
#problem 1

marks_list = []

for i in range(0,5):
    sub_name = input(f"Enter subject {i+1} name")
    sub_mark = int(input(f"Enter subject {i+1} marks"))
    marks_list.append(sub_mark)

average = sum(marks_list) / len(marks_list)
print(average)

if average >= 80: print("A Grade")
elif average < 80 and average >= 60: print("B Grade")
elif average < 60 and average >= 40: print("C Grade")
else:
    print("F Grade")
# Out:
# Enter subject 1 name m
# Enter subject 1 marks 12
# Enter subject 2 name k
# Enter subject 2 marks 12
# Enter subject 3 name k
# Enter subject 3 marks 12
# Enter subject 4 name e
# Enter subject 4 marks 12
# Enter subject 5 name e
# Enter subject 5 marks 12
# 12.0
# F Grade

# %%
#problem 2

string_sentence = input("Enter a sentence")
word_count = len(string_sentence.split(' '))
print(f"This is the word count i have: {word_count}")

char_count = len(string_sentence)
print(f"This is the char count i have: {char_count}")

vowel = ['a', 'e', 'i', 'o', 'u']
vowel_count = 0
consonant_count = 0
for ch in string_sentence:
    if ch in vowel:
        vowel_count+=1
    else:
        consonant_count += 1

print(f"This is the vowel count i have: {vowel_count}")
print(f"This is the consonant count i have: {consonant_count}")
# Out:
# Enter a sentence adi
# This is the word count i have: 1
# This is the char count i have: 3
# This is the vowel count i have: 2
# This is the consonant count i have: 1

# %%
# problem 3

user_list_intger = []

end = int(input("Enter the length of a list"))

for i in range(0, end):
    num = int(input("Enter the number:"))
    user_list_intger.append(num)

print(user_list_intger)

even_list = []
odd_list = []

for i in user_list_intger:
    if i % 2 == 0:
        even_list.append(i)
    else:
        odd_list.append(i)

print(f"Even list: {even_list}")
print(f"Odd list : {odd_list}")
# Out:
# Enter the length of a list 3
# Enter the number: 2
# Enter the number: 3
# Enter the number: 43
# [2, 3, 43]
# Even list: [2]
# Odd list : [3, 43]

# %%
#problem 4

user_list_integer = []

end = int(input("Enter the length of a list"))

for i in range(0, end):
    num = int(input("Enter the number:"))
    user_list_integer.append(num)

print(user_list_intger)

numbers = user_list_integer

total = 0

largest = numbers[0]
smallest = numbers[0]

for number in numbers:
    total = total + number

    if number > largest:
        largest = number
    if number < smallest:
        smallest = number
average = total / len(numbers)

print(f"Largest: {largest}")
print(f"Smallest: {smallest}")
print(f"Total: {total}")
print(f"Average: {average}")
# Out:
# Enter the length of a list 3
# Enter the number: 1
# Enter the number: 2
# Enter the number: 3
# [1, 2, 3]
# Largest: 3
# Smallest: 1
# Total: 6
# Average: 2.0

# %%
# problem 5


string_input = input("Enter a string").lower().replace(" ", "")

rev_str_input = string_input[::-1]

if rev_str_input == string_input:
    print("Palindrome")
else:
    print("Not a Palindrome")
# Out:
# Enter a string adi dia
# Not a Palindrome

# %%
mark_len = int(input("Enter the length of list"))

marks_list = [int(input(f"Enter marks {i+1}")) for i in range(mark_len)]

marks_tuple = tuple(marks_list)

print(marks_tuple)

average = sum(marks_tuple) / len(marks_tuple)
max_marks = max(marks_tuple)
lowest_marks = min(marks_tuple)

print(f"Maximum Marks {lowest_marks}")
print(f"Lowest Marks {max_marks}")
count = 0
for i in marks_tuple:
    if i > average:
        count += 1
print(f"Number of students scoring above average: {count}")
# Out:
# Enter the length of list 3
# Enter marks 1 2
# Enter marks 2 3
# Enter marks 3 4
# (2, 3, 4)
# Maximum Marks 2
# Lowest Marks 4
# Number of students scoring above average: 1

# %%
num = int(input("Enter the num of students you want"))

dict_marks = {}

for i in range(0, num):
    name = input("Enter the name of student")
    marks = int(input("Enter the marks of students"))
    dict_marks.update({name:marks})

print(dict_marks)

stu_name = input("enter student name")

if stu_name in dict_marks:
    print(f"Marks:{dict_marks[stu_name]}")
else:
    print("Student not found")
# Out:
# Enter the num of students you want 3
# Enter the name of student adi
# Enter the marks of students 21
# Enter the name of student adita
# Enter the marks of students 56
# Enter the name of student sai
# Enter the marks of students 34
# {'adi': 21, 'adita': 56, 'sai': 34}
# enter student name 12
# Student not found

# %%
string_input = input("Enter a string")

dict_string = {}

for ch in string_input:
    ch_cnt = string_input.count(ch)
    dict_string.update({ch:ch_cnt})

print(dict_string)
# Out:
# Enter a string bananna
# {'b': 1, 'a': 3, 'n': 3}

# %%
set1 = set([input("Enter set 1:") for i in range(0,5)])
set2 = set(input("Enter set 2:")  for i in range(0,5) )
print(f"Union:{set1.union(set2)}") # s1 | s2
print(f"Intersection: {set1.intersection(set2)}") # s1 & s2
print(f"Difference: {set1.difference(set2)}") #s1 - s2
print(f"Symmetric difference {set1.difference(set2)}") #s1 ^ s2
# Out:
# Enter set 1: 3
# Enter set 1: 3
# Enter set 1: 4
# Enter set 1: 5
# Enter set 1: 23
# Enter set 2: 4
# Enter set 2: 54
# Enter set 2: 3
# Enter set 2: 232
# Enter set 2: 3
# Union:{'232', '5', '54', '23', '3', '4'}
# Intersection: {'3', '4'}
# Difference: {'23', '5'}
# Symmetric difference {'23', '5'}

# %%
# contact book

contacts = {}

while True:
    print("------ Contact Book ------")
    print(" '1': Add, '2': Search, '3': Update, '4':Delete, '5':Display, '6': Exit ")
    choice = input("Enter your choice")[0]
    if choice == '1':
        print("Add a contact")
        name = input("Enter name of contact")
        phone_no = int(input("Enter contact number"))
        contacts.update({name:phone_no})
    elif choice == '2':
        name = input("Enter name to search:")
        if name in contacts:
            print(f"Phone: {contacts[name]}")
        else:
            print("Contact not found")
    elif choice == '3':
        name = input("Enter name to update:")
        if name in contacts:
            number = input("Enter new phone number:")
            contacts[name] = number
        else:
            print("Contact not found.")
    elif choice == "4":
        name = input("Enter name to delete:")
        if name in contacts:
            del contacts[name]
            print("Contact deleted sucessfully")
        else:
            print("Contact not found")
    elif choice == "5":
        if len(contacts) == 0:
            print("No contacts available")
        else:
            for name, number in contacts.items():
                print(name,":",number)
    elif choice == "6":
        print("Exiting Contact Book...")
        break
    else:
        print("Invalid choice")
# Out:
# ------ Contact Book ------
#  '1': Add, '2': Search, '3': Update, '4':Delete, '5':Display, '6': Exit
# Enter your choice 6
# Exiting Contact Book...
